# %%
import pandas as pd

# %%
df_exam = pd.read_excel('excel_exam.xlsx')
df_exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
sum(df_exam['english'])/20
# Out:
# 84.9

# %%
sum(df_exam['science'])/20
# Out:
# 59.45

# %%
df = pd.DataFrame({'a':[1,2,3],
                  'b':[4,5,6]})
df
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
len(df_exam)
# Out:
# 20

# %%
sum(df_exam['english'])/len(df_exam)
# Out:
# 84.9

# %%
sum(df_exam['science'])/len(df_exam)
# Out:
# 59.45

# %%
df_exam_novar = pd.read_excel('excel_exam_novar.xlsx')

# %%
df_exam_novar
# Out:
#    1  1.1  50  98  50.1
# 0  2    1  60  97    60
# 1  3    2  25  80    65
# 2  4    2  50  89    98
# 3  5    3  20  98    15
# 4  6    3  50  98    45
# 5  7    4  46  98    65
# 6  8    4  48  87    12

# %%
df_exam_novar = pd.read_excel('excel_exam_novar.xlsx', header = None)
df_exam_novar
# Out:
#    0  1   2   3   4
# 0  1  1  50  98  50
# 1  2  1  60  97  60
# 2  3  2  25  80  65
# 3  4  2  50  89  98
# 4  5  3  20  98  15
# 5  6  3  50  98  45
# 6  7  4  46  98  65
# 7  8  4  48  87  12

# %%
df_exam = pd.read_excel('excel_exam.xlsx', sheet_name = 2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 df_exam = pd.read_excel('excel_exam.xlsx', sheet_name = 2)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/excel/_base.py:465, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     459     raise ValueError(
#     460         "Engine should not be specified when passing "
#     461         "an ExcelFile - ExcelFile already has the engine set"
#     462     )
#     464 try:
# --> 465     data = io.parse(
#     466         sheet_name=sheet_name,
#     467         header=header,
#     468         names=names,
#     469         index_col=index_col,
#     470         usecols=usecols,
#     471         squeeze=squeeze,
#     472         dtype=dtype,
#     473         converters=converters,
#     474         true_values=true_values,
#     475         false_values=false_values,
#     476         skiprows=skiprows,
#     477         nrows=nrows,
#     478         na_values=na_values,
#     479         keep_default_na=keep_default_na,
#     480         na_filter=na_filter,
#     481         verbose=verbose,
#     482         parse_dates=parse_dates,
#     483         date_parser=date_parser,
#     484         thousands=thousands,
#     485         decimal=decimal,
#     486         comment=comment,
#     487         skipfooter=skipfooter,
#     488         convert_float=convert_float,
#     489         mangle_dupe_cols=mangle_dupe_cols,
#     490     )
#     491 finally:
#     492     # make sure to close opened file handles
#     493     if should_close:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/excel/_base.py:1458, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, squeeze, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#    1424 def parse(
#    1425     self,
#    1426     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)
#    1445     **kwds,
#    1446 ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    1447     """
#    1448     Parse specified sheet(s) into a DataFrame.
#    1449
#    (...)
#    1456         DataFrame from the passed in Excel file.
#    1457     """
# -> 1458     return self._reader.parse(
#    1459         sheet_name=sheet_name,
#    1460         header=header,
#    1461         names=names,
#    1462         index_col=index_col,
#    1463         usecols=usecols,
#    1464         squeeze=squeeze,
#    1465         converters=converters,
#    1466         true_values=true_values,
#    1467         false_values=false_values,
#    1468         skiprows=skiprows,
#    1469         nrows=nrows,
#    1470         na_values=na_values,
#    1471         parse_dates=parse_dates,
#    1472         date_parser=date_parser,
#    1473         thousands=thousands,
#    1474         comment=comment,
#    1475         skipfooter=skipfooter,
#    1476         convert_float=convert_float,
#    1477         mangle_dupe_cols=mangle_dupe_cols,
#    1478         **kwds,
#    1479     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/excel/_base.py:636, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, squeeze, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     634     sheet = self.get_sheet_by_name(asheetname)
#     635 else:  # assume an integer if not a string
# --> 636     sheet = self.get_sheet_by_index(asheetname)
#     638 data = self.get_sheet_data(sheet, convert_float)
#     639 if hasattr(sheet, "close"):
#     640     # pyxlsb opens two TemporaryFiles
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/excel/_openpyxl.py:549, in OpenpyxlReader.get_sheet_by_index(self, index)
#     548 def get_sheet_by_index(self, index: int):
# --> 549     self.raise_if_bad_sheet_by_index(index)
#     550     return self.book.worksheets[index]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/excel/_base.py:564, in BaseExcelReader.raise_if_bad_sheet_by_index(self, index)
#     562 n_sheets = len(self.sheet_names)
#     563 if index >= n_sheets:
# --> 564     raise ValueError(
#     565         f"Worksheet index {index} is invalid, {n_sheets} worksheets found"
#     566     )
#
# ValueError: Worksheet index 2 is invalid, 1 worksheets found

# %%
df_csv_exam = pd.read_csv('exam.csv')
df_csv_exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
df_midterm = pd.DataFrame({'english':[90,80,60,70],
                          'math':[50,60,100,20],
                          'nclass':[1,1,2,2]})
df_midterm
# Out:
#    english  math  nclass
# 0       90    50       1
# 1       80    60       1
# 2       60   100       2
# 3       70    20       2
