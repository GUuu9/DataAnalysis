# %%
import pandas as pd

# %% [raw]
# #query()       | 행 추출
# #df[]          | 열 추출
# #sort_values() | 정렬
# #groupby()     | 집단별로 나누기
# #assing()      | 변수 추가
# #agg()         | 통계치 구하기
# #merge()       | 데이터합치기(열)
# #concat()      | 데이터합치기(행)

# %%
exam = pd.read_csv('exam.csv')
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('nclass == 1') # exam에서 nclass가 1인 경우에만 추출
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
exam.query('nclass == 2')
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
exam.query('nclass != 1') # == : 동일한 데이터 | != : 같지 않은 데이터 | <, >, <=, >= 대소 비교
# Out:
#     id  nclass  math  english  science
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('math < 50')
# Out:
#     id  nclass  math  english  science
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 8    9       3    20       98       15
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12

# %%
exam.query('math > 50')
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 10  11       3    65       65       65
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('english >= 50')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('english <= 80')
# Out:
#     id  nclass  math  english  science
# 4    5       2    25       80       65
# 7    8       2    90       78       25
# 10  11       3    65       65       65
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87

# %% [raw]
# # & : and 연산자 양측의 조건을 모두 만족하는 데이터
# # | : or 연산자 양측의 조건중 하나라도 충족된 데이터

# %%
exam.query('nclass == 1 & math >= 1')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
exam.query('nclass == 2 & english >= 80')
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45

# %%
exam.query('math >= 90 | english >= 90')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 12  13       4    46       98       65
# 15  16       4    58       98       65

# %%
exam.query('english < 90 | science < 50')
# Out:
#     id  nclass  math  english  science
# 2    3       1    45       86       78
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('nclass == 1 | nclass == 3 | nclass == 5')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('nclass in [1,3,5]')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
nclass1 = exam.query('nclass == 1')
nclass2 = exam.query('nclass == 2')

# %%
nclass1['math'].mean()
# Out:
# 46.25

# %%
nclass2['math'].mean()
# Out:
# 61.25

# %%
df = pd.DataFrame({'sex':['F','M','F','M'],
                  'country' : ['Korea', 'China', 'Japen', 'USA']})
df
# Out:
#   sex country
# 0   F   Korea
# 1   M   China
# 2   F   Japen
# 3   M     USA

# %%
df.query('sex == "F" & country == "Korea"')
# Out:
#   sex country
# 0   F   Korea

# %%
df.query("sex == 'F' & country == 'Korea'")
# Out:
#   sex country
# 0   F   Korea

# %%
exam['math']
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
exam['english']
# Out:
# 0     98
# 1     97
# 2     86
# 3     98
# 4     80
# 5     89
# 6     90
# 7     78
# 8     98
# 9     98
# 10    65
# 11    85
# 12    98
# 13    87
# 14    56
# 15    98
# 16    68
# 17    78
# 18    68
# 19    83
# Name: english, dtype: int64

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam[['nclass', 'math', 'english']]
# Out:
#     nclass  math  english
# 0        1    50       98
# 1        1    60       97
# 2        1    45       86
# 3        1    30       98
# 4        2    25       80
# 5        2    50       89
# 6        2    80       90
# 7        2    90       78
# 8        3    20       98
# 9        3    50       98
# 10       3    65       65
# 11       3    45       85
# 12       4    46       98
# 13       4    48       87
# 14       4    75       56
# 15       4    58       98
# 16       5    65       68
# 17       5    80       78
# 18       5    89       68
# 19       5    78       83

# %%
exam.drop(columns = 'math')
# Out:
#     id  nclass  english  science
# 0    1       1       98       50
# 1    2       1       97       60
# 2    3       1       86       78
# 3    4       1       98       58
# 4    5       2       80       65
# 5    6       2       89       98
# 6    7       2       90       45
# 7    8       2       78       25
# 8    9       3       98       15
# 9   10       3       98       45
# 10  11       3       65       65
# 11  12       3       85       32
# 12  13       4       98       65
# 13  14       4       87       12
# 14  15       4       56       78
# 15  16       4       98       65
# 16  17       5       68       98
# 17  18       5       78       90
# 18  19       5       68       87
# 19  20       5       83       58

# %%
exam.drop(columns = ['math', 'english'])
# Out:
#     id  nclass  science
# 0    1       1       50
# 1    2       1       60
# 2    3       1       78
# 3    4       1       58
# 4    5       2       65
# 5    6       2       98
# 6    7       2       45
# 7    8       2       25
# 8    9       3       15
# 9   10       3       45
# 10  11       3       65
# 11  12       3       32
# 12  13       4       65
# 13  14       4       12
# 14  15       4       78
# 15  16       4       65
# 16  17       5       98
# 17  18       5       90
# 18  19       5       87
# 19  20       5       58

# %%
exam.query('nclass == 1')['english']
# Out:
# 0    98
# 1    97
# 2    86
# 3    98
# Name: english, dtype: int64

# %%
exam.query('math >= 50')[['id','math']]
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75
# 15  16    58
# 16  17    65
# 17  18    80
# 18  19    89
# 19  20    78

# %%
exam.query('math >= 50')[['id','math']].head()
# Out:
#    id  math
# 0   1    50
# 1   2    60
# 5   6    50
# 6   7    80
# 7   8    90

# %%
exam.query('math >= 50')[['id', 'math']].head(10)
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75
# 15  16    58
# 16  17    65

# %% [raw]
# # 가독성을 위해 \ 기호를 통해 행을 바꿀 수 있다.

# %%
exam.query('math >= 50') \
[['id', 'math']] \
.head()
# Out:
#    id  math
# 0   1    50
# 1   2    60
# 5   6    50
# 6   7    80
# 7   8    90

# %%
mpg = pd.read_csv('mpg.csv')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
mpg_use = mpg[['category', 'cty']]
mpg_use
# Out:
#     category  cty
# 0    compact   18
# 1    compact   21
# 2    compact   20
# 3    compact   21
# 4    compact   16
# ..       ...  ...
# 229  midsize   19
# 230  midsize   21
# 231  midsize   16
# 232  midsize   18
# 233  midsize   17
#
# [234 rows x 2 columns]

# %%
mpg_use.query('category == "compact"')['cty'].mean()
# Out:
# 20.127659574468087

# %%
mpg_use.query('category == "suv"')['cty'].mean()
# Out:
# 13.5

# %%
exam.sort_values('math')
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 4    5       2    25       80       65
# 3    4       1    30       98       58
# 2    3       1    45       86       78
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 0    1       1    50       98       50
# 9   10       3    50       98       45
# 5    6       2    50       89       98
# 15  16       4    58       98       65
# 1    2       1    60       97       60
# 10  11       3    65       65       65
# 16  17       5    65       68       98
# 14  15       4    75       56       78
# 19  20       5    78       83       58
# 6    7       2    80       90       45
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 7    8       2    90       78       25

# %%
exam.sort_values('math', ascending = False)
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 6    7       2    80       90       45
# 19  20       5    78       83       58
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 10  11       3    65       65       65
# 1    2       1    60       97       60
# 15  16       4    58       98       65
# 9   10       3    50       98       45
# 5    6       2    50       89       98
# 0    1       1    50       98       50
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 11  12       3    45       85       32
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 8    9       3    20       98       15

# %%
exam.sort_values(['nclass', 'math'])
# Out:
#     id  nclass  math  english  science
# 3    4       1    30       98       58
# 2    3       1    45       86       78
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 11  12       3    45       85       32
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 15  16       4    58       98       65
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 19  20       5    78       83       58
# 17  18       5    80       78       90
# 18  19       5    89       68       87

# %%
exam.sort_values(['nclass', 'math'], ascending = [True, False])
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 0    1       1    50       98       50
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 7    8       2    90       78       25
# 6    7       2    80       90       45
# 5    6       2    50       89       98
# 4    5       2    25       80       65
# 10  11       3    65       65       65
# 9   10       3    50       98       45
# 11  12       3    45       85       32
# 8    9       3    20       98       15
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 19  20       5    78       83       58
# 16  17       5    65       68       98

# %%
mpg = pd.read_csv('mpg.csv')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
mpg.query('manufacturer == "audi"').sort_values('hwy', ascending = False).head()
# Out:
#   manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 2         audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3         audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 0         audi          a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1         audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 9         audi  a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p
#
#   category
# 2  compact
# 3  compact
# 0  compact
# 1  compact
# 9  compact

# %%
exam.assign(total = exam['math'] + exam['english'] + exam['science'])
# Out:
#     id  nclass  math  english  science  total
# 0    1       1    50       98       50    198
# 1    2       1    60       97       60    217
# 2    3       1    45       86       78    209
# 3    4       1    30       98       58    186
# 4    5       2    25       80       65    170
# 5    6       2    50       89       98    237
# 6    7       2    80       90       45    215
# 7    8       2    90       78       25    193
# 8    9       3    20       98       15    133
# 9   10       3    50       98       45    193
# 10  11       3    65       65       65    195
# 11  12       3    45       85       32    162
# 12  13       4    46       98       65    209
# 13  14       4    48       87       12    147
# 14  15       4    75       56       78    209
# 15  16       4    58       98       65    221
# 16  17       5    65       68       98    231
# 17  18       5    80       78       90    248
# 18  19       5    89       68       87    244
# ...

# %%
exam.assign(total = exam['math'] + exam['english'] + exam['science'], 
            mean = (exam['math'] + exam['english'] + exam['science'])/3)
# Out:
#     id  nclass  math  english  science  total       mean
# 0    1       1    50       98       50    198  66.000000
# 1    2       1    60       97       60    217  72.333333
# 2    3       1    45       86       78    209  69.666667
# 3    4       1    30       98       58    186  62.000000
# 4    5       2    25       80       65    170  56.666667
# 5    6       2    50       89       98    237  79.000000
# 6    7       2    80       90       45    215  71.666667
# 7    8       2    90       78       25    193  64.333333
# 8    9       3    20       98       15    133  44.333333
# 9   10       3    50       98       45    193  64.333333
# 10  11       3    65       65       65    195  65.000000
# 11  12       3    45       85       32    162  54.000000
# 12  13       4    46       98       65    209  69.666667
# 13  14       4    48       87       12    147  49.000000
# 14  15       4    75       56       78    209  69.666667
# ...

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
import numpy as np
exam.assign(test = np.where(exam['science'] >= 60, 'pass', 'fall'))
# Out:
#     id  nclass  math  english  science  test
# 0    1       1    50       98       50  fall
# 1    2       1    60       97       60  pass
# 2    3       1    45       86       78  pass
# 3    4       1    30       98       58  fall
# 4    5       2    25       80       65  pass
# 5    6       2    50       89       98  pass
# 6    7       2    80       90       45  fall
# 7    8       2    90       78       25  fall
# 8    9       3    20       98       15  fall
# 9   10       3    50       98       45  fall
# 10  11       3    65       65       65  pass
# 11  12       3    45       85       32  fall
# 12  13       4    46       98       65  pass
# 13  14       4    48       87       12  fall
# 14  15       4    75       56       78  pass
# 15  16       4    58       98       65  pass
# 16  17       5    65       68       98  pass
# 17  18       5    80       78       90  pass
# 18  19       5    89       68       87  pass
# 19  20       5    78       83       58  fall

# %%
exam.assign(total = exam['math'] + exam['english'] + exam['science']).sort_values('total')
# Out:
#     id  nclass  math  english  science  total
# 8    9       3    20       98       15    133
# 13  14       4    48       87       12    147
# 11  12       3    45       85       32    162
# 4    5       2    25       80       65    170
# 3    4       1    30       98       58    186
# 9   10       3    50       98       45    193
# 7    8       2    90       78       25    193
# 10  11       3    65       65       65    195
# 0    1       1    50       98       50    198
# 2    3       1    45       86       78    209
# 12  13       4    46       98       65    209
# 14  15       4    75       56       78    209
# 6    7       2    80       90       45    215
# 1    2       1    60       97       60    217
# 19  20       5    78       83       58    219
# 15  16       4    58       98       65    221
# 16  17       5    65       68       98    231
# 5    6       2    50       89       98    237
# 18  19       5    89       68       87    244
# ...

# %%
long_name = pd.read_csv('exam.csv')

# %%
long_name.assign(new = long_name['math'] + long_name['english'] + long_name['science'])
# Out:
#     id  nclass  math  english  science  new
# 0    1       1    50       98       50  198
# 1    2       1    60       97       60  217
# 2    3       1    45       86       78  209
# 3    4       1    30       98       58  186
# 4    5       2    25       80       65  170
# 5    6       2    50       89       98  237
# 6    7       2    80       90       45  215
# 7    8       2    90       78       25  193
# 8    9       3    20       98       15  133
# 9   10       3    50       98       45  193
# 10  11       3    65       65       65  195
# 11  12       3    45       85       32  162
# 12  13       4    46       98       65  209
# 13  14       4    48       87       12  147
# 14  15       4    75       56       78  209
# 15  16       4    58       98       65  221
# 16  17       5    65       68       98  231
# 17  18       5    80       78       90  248
# 18  19       5    89       68       87  244
# 19  20       5    78       83       58  219

# %%
long_name.assign(new = lambda x: x['math'] + x['english'] + x['science'])
# Out:
#     id  nclass  math  english  science  new
# 0    1       1    50       98       50  198
# 1    2       1    60       97       60  217
# 2    3       1    45       86       78  209
# 3    4       1    30       98       58  186
# 4    5       2    25       80       65  170
# 5    6       2    50       89       98  237
# 6    7       2    80       90       45  215
# 7    8       2    90       78       25  193
# 8    9       3    20       98       15  133
# 9   10       3    50       98       45  193
# 10  11       3    65       65       65  195
# 11  12       3    45       85       32  162
# 12  13       4    46       98       65  209
# 13  14       4    48       87       12  147
# 14  15       4    75       56       78  209
# 15  16       4    58       98       65  221
# 16  17       5    65       68       98  231
# 17  18       5    80       78       90  248
# 18  19       5    89       68       87  244
# 19  20       5    78       83       58  219

# %%
df = mpg.copy()
df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
df.assign(sum_of_oil = df['cty'] + df['hwy'])
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category  sum_of_oil
# 0    compact          47
# 1    compact          50
# ...

# %%
df.assign(sum_of_oil = lambda x: x['cty'] + x['hwy'],
         mean_of_oil = lambda x: x['sum_of_oil']/2)
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category  sum_of_oil  mean_of_oil
# 0    compact          47         23.5
# ...

# %%
df.assign(sum_of_oil = lambda x: x['cty'] + x['hwy'],
         mean_of_oil = lambda x: x['sum_of_oil']/2).sort_values('mean_of_oil').head(3)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 54         dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 126         jeep   grand cherokee 4wd    4.7  2008    8    auto(l5)   4    9
# 69         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    9
#
#      hwy fl category  sum_of_oil  mean_of_oil
# 54    12  e   pickup          21         10.5
# 126   12  e      suv          21         10.5
# 69    12  e   pickup          21         10.5

# %%
exam.agg(mean_math = ('math', 'mean'))
# Out:
#             math
# mean_math  57.45

# %%
exam.groupby('nclass').agg(mean_math = ('math', 'mean'))
# Out:
#         mean_math
# nclass
# 1           46.25
# 2           61.25
# 3           45.00
# 4           56.75
# 5           78.00

# %%
exam.groupby('nclass', as_index = False).agg(mean_math = ('math', 'mean'))
# Out:
#    nclass  mean_math
# 0       1      46.25
# 1       2      61.25
# 2       3      45.00
# 3       4      56.75
# 4       5      78.00

# %%
exam.groupby('nclass').agg(mean_math = ('math', 'mean'),
                          sum_math = ('math', 'sum'),
                          median_math = ('math', 'median'),
                          n = ('nclass', 'count'))
# Out:
#         mean_math  sum_math  median_math  n
# nclass
# 1           46.25       185         47.5  4
# 2           61.25       245         65.0  4
# 3           45.00       180         47.5  4
# 4           56.75       227         53.0  4
# 5           78.00       312         79.0  4

# %%
exam.groupby('nclass').mean()
# Out:
#           id   math  english  science
# nclass
# 1        2.5  46.25    94.75    61.50
# 2        6.5  61.25    84.25    58.25
# 3       10.5  45.00    86.50    39.25
# 4       14.5  56.75    84.75    55.00
# 5       18.5  78.00    74.25    83.25

# %%
mpg.groupby(['manufacturer', 'drv']).agg(mean_cty = ('cty', 'mean'))
# Out:
#                    mean_cty
# manufacturer drv
# audi         4    16.818182
#              f    18.857143
# chevrolet    4    12.500000
#              f    18.800000
#              r    14.100000
# dodge        4    12.000000
#              f    15.818182
# ford         4    13.307692
#              r    14.750000
# honda        f    24.444444
# hyundai      f    18.642857
# jeep         4    13.500000
# land rover   4    11.500000
# lincoln      r    11.333333
# mercury      4    13.250000
# nissan       4    13.750000
#              f    20.000000
# pontiac      f    17.000000
# subaru       4    19.285714
# toyota       4    14.933333
#              f    21.368421
# volkswagen   f    20.925926

# %%
mpg.query('manufacturer == "audi"').groupby(['drv']).agg(n = ('drv', 'count'))
# Out:
#       n
# drv
# 4    11
# f     7

# %%
mpg.query('manufacturer == "chevrolet"').groupby(['drv']).agg(n = ('drv', 'count'))
# Out:
#       n
# drv
# 4     4
# f     5
# r    10

# %%
mpg.groupby('drv').agg(n = ('drv', 'count'))
# Out:
#        n
# drv
# 4    103
# f    106
# r     25

# %%
mpg['drv'].value_counts()
# Out:
# f    106
# 4    103
# r     25
# Name: drv, dtype: int64

# %%
#mpg['drv'].value_counts().query('n > 100') <- 불가
mpg['drv'].value_counts().to_frame('n').rename_axis('drv').query('n > 100')
# Out:
#        n
# drv
# f    106
# 4    103

# %%
mpg.query('category == "suv"').assign(total = (mpg['hwy'] + mpg['cty'])/2)\
.groupby('manufacturer').agg(mean_tot = ('total', 'mean'))\
.sort_values('mean_tot', ascending = False).head()
# Out:
#                mean_tot
# manufacturer
# subaru        21.916667
# toyota        16.312500
# nissan        15.875000
# mercury       15.625000
# jeep          15.562500

# %%
mpg = pd.read_csv('mpg.csv')
mpg.groupby('category').agg(mean_cty = ('cty', 'mean'))
# Out:
#              mean_cty
# category
# 2seater     15.400000
# compact     20.127660
# midsize     18.756098
# minivan     15.818182
# pickup      13.000000
# subcompact  20.371429
# suv         13.500000

# %%
mpg.groupby('category').agg(mean_cty = ('cty', 'mean')).sort_values('mean_cty', ascending = False)
# Out:
#              mean_cty
# category
# subcompact  20.371429
# compact     20.127660
# midsize     18.756098
# minivan     15.818182
# 2seater     15.400000
# suv         13.500000
# pickup      13.000000

# %%
mpg.groupby('manufacturer').agg(mean_hwy = ('hwy', 'mean')).sort_values('mean_hwy', ascending = False).head(3)
# Out:
#                mean_hwy
# manufacturer
# honda         32.555556
# volkswagen    29.222222
# hyundai       26.857143

# %%
#1
mpg.query('category == "compact"')\
.groupby('manufacturer').agg(n = ('manufacturer', 'count')).sort_values('n', ascending = False)
# Out:
#                n
# manufacturer
# audi          15
# volkswagen    14
# toyota        12
# subaru         4
# nissan         2

# %%
#2
mpg.query('category == "compact"').value_counts('manufacturer')
# Out:
# manufacturer
# audi          15
# volkswagen    14
# toyota        12
# subaru         4
# nissan         2
# dtype: int64
